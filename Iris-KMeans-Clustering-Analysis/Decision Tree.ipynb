# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.metrics import confusion_matrix
import graphviz
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv("Irıs_Data_Set.csv")
#data=load_iris()
#df=pd.DataFrame(data.data,columns=data.feature_names)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
X=iris[["sepal_length","sepal_width","petal_length","petal_width"]].values
X[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
Y=iris["species"]
#Y[0:5]
Y.sample(5)
# Out:
# 36        Iris-setosa
# 51    Iris-versicolor
# 49        Iris-setosa
# 79    Iris-versicolor
# 47        Iris-setosa
# Name: species, dtype: object

# %%
X_trainset,X_testset,Y_trainset,Y_testset=train_test_split(X,Y,test_size=0.3,random_state=3)

# %%
#Decision-Tree Classifier with Gini index
SpeciesTree=DecisionTreeClassifier(criterion="gini",max_depth=4)
SpeciesTree# it shows the default parameters
SpeciesTree.fit(X_trainset,Y_trainset)
predTree=SpeciesTree.predict(X_testset)
print(predTree[0:5])
print(Y_testset[0:5])
cn=iris["species"].unique().tolist()
fn=iris.columns[0:5]
SpeciesTree.fit(X,Y)
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(10,10),dpi=300)
tree.plot_tree(SpeciesTree,feature_names=fn,class_names=cn,filled=True);
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa']
# 47    Iris-setosa
# 3     Iris-setosa
# 31    Iris-setosa
# 25    Iris-setosa
# 15    Iris-setosa
# Name: species, dtype: object

# %%
classifier = DecisionTreeClassifier()

classifier.fit(X_trainset, Y_trainset)

y_pred = classifier.predict(X_testset)

# Summary of the predictions made by the classifier

# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,Y_testset))
# Out:
# accuracy is 0.9555555555555556

# %%
print(classification_report(Y_testset, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.93      0.93      0.93        14
#  Iris-virginica       0.93      0.93      0.93        14
#
#        accuracy                           0.96        45
#       macro avg       0.95      0.95      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(confusion_matrix(Y_testset, y_pred))
# Out:
# [[17  0  0]
#  [ 0 13  1]
#  [ 0  1 13]]

# %%
SpeciesTree=DecisionTreeClassifier(criterion="entropy",max_depth=4)
SpeciesTree# it shows the default parameters
SpeciesTree.fit(X_trainset,Y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
predTree=SpeciesTree.predict(X_testset)
print(predTree[0:5])
print(Y_testset[0:5])
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa']
# 47    Iris-setosa
# 3     Iris-setosa
# 31    Iris-setosa
# 25    Iris-setosa
# 15    Iris-setosa
# Name: species, dtype: object

# %%
# Confusion Matrix
y_pred=np.zeros(10000)
y_test=np.zeros(10000)
indices1=np.random.randint(0,10000,300)
indices2=np.random.randint(0,10000,400)
indices3=np.random.randint(0,10000,500)
y_pred[indices1]=1
y_test[indices2]=1
y_pred[indices3]=1
y_test[indices3]=1

# %%
from sklearn.metrics import precision_recall_curve
precision,recall,thresholds=precision_recall_curve(y_test,y_pred)

# %%
precision
# Out:
# array([0.0862    , 0.65494792, 1.        ])

# %%
recall
# Out:
# array([1.        , 0.58352668, 0.        ])

# %%
cn=iris["species"].unique().tolist()
fn=iris.columns[0:5]
SpeciesTree.fit(X,Y)
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(10,10),dpi=300)
tree.plot_tree(SpeciesTree,feature_names=fn,class_names=cn,filled=True);


cn=iris["species"].unique().tolist()
fn=iris.columns[0:5]
SpeciesTree.fit(X,Y)
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(10,10),dpi=300)
tree.plot_tree(SpeciesTree,feature_names=fn,class_names=cn,filled=True);

# %%
SpeciesTree=DecisionTreeClassifier(criterion="entropy",max_depth=4)
SpeciesTree# it shows the default parameters
SpeciesTree.fit(X_trainset,Y_trainset)
predTree=SpeciesTree.predict(X_testset)
print(predTree[0:5])
print(Y_testset.sample(5))
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa']
# 111     Iris-virginica
# 41         Iris-setosa
# 140     Iris-virginica
# 57     Iris-versicolor
# 6          Iris-setosa
# Name: species, dtype: object

# %%
classifier = DecisionTreeClassifier()

classifier.fit(X_trainset, Y_trainset)

y_pred = classifier.predict(X_testset)

# Summary of the predictions made by the classifier

# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,Y_testset))
# Out:
# accuracy is 0.8888888888888888

# %%
print(classification_report(Y_testset, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.91      0.71      0.80        14
#  Iris-virginica       0.76      0.93      0.84        14
#
#        accuracy                           0.89        45
#       macro avg       0.89      0.88      0.88        45
#    weighted avg       0.90      0.89      0.89        45

# %%
print(confusion_matrix(Y_testset, y_pred))
# Out:
# [[17  0  0]
#  [ 0 10  4]
#  [ 0  1 13]]

# %%
print("Gini index:It is used to determine the classes of the added data by looking at the previous data.\n")
print("Entropy index:The entropy value expresses the disorder of the data set.\n")
print("Confusion matrix: A table that separates a data set with true and predicted values into true or false.\n")
print("ACCURACY: calculates the accuracy of an algorithm,If the accuracy of the data is wrong but correct when the classification is done,")
print("\t (TP)If the accuracy of the data is correct and the classification is correct, the correct positive value is ")
print("\t (FP)If the accuracy of the data is wrong but correct when the classification is done,it will be a false positive value")
print("\t (TN)If the accuracy of the data is correct but the classification is incorrect, the correct is a negative value")
print("\t (FN)If the accuracy of the data is incorrect and incorrect when the classification is made,it will be a false n. value ")
print("\t Accuracy Formula:(TP+TN/TP+TN+FP+FN)")
print("Precision: Also known as Positive Predictive Value. calculates the ratio of correctly predicted values to positive values of the dataset (it should be as high as possible).")
print("\t Precision Formula:TP/(TP+FP)")
print("Recall: Recall is the ratio of what we should have predicted as positive to positive predictions. This value should be as high as possible -(same precision).")
print("\t Recall Formula:TP/(TP+FN)")
print("f1 score: Measures the accuracy of the model in the dataset, but Accuracy will not always be a measure for choosing the best model. so f1 score is used. Its best value at 1 and worst value at 0")
print("\t f1:2*(PRECISION*RECALL)/(PRECISION+RECALL)")
# Out:
# Gini index:It is used to determine the classes of the added data by looking at the previous data.
#
# Entropy index:The entropy value expresses the disorder of the data set.
#
# Confusion matrix: A table that separates a data set with true and predicted values into true or false.
#
# ACCURACY: calculates the accuracy of an algorithm,If the accuracy of the data is wrong but correct when the classification is done,
# 	 (TP)If the accuracy of the data is correct and the classification is correct, the correct positive value is
# 	 (FP)If the accuracy of the data is wrong but correct when the classification is done,it will be a false positive value
# 	 (TN)If the accuracy of the data is correct but the classification is incorrect, the correct is a negative value
# 	 (FN)If the accuracy of the data is incorrect and incorrect when the classification is made,it will be a false n. value
# 	 Accuracy Formula:(TP+TN/TP+TN+FP+FN)
# ...
